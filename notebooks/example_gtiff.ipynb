# %%
import rioxarray

# %% [markdown]
# # Load GeoTIFF data
#
# Load the sample image data file

# %%
sample = rioxarray.open_rasterio("../images/sample.tif")

# %% [markdown]
# View the metadata for the image array

# %%
sample
# Out:
# <xarray.DataArray (band: 3, y: 1001, x: 1001)> Size: 6MB
# [3006003 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 8kB 5.905e+05 5.905e+05 ... 6.005e+05 6.005e+05
#   * y            (y) float64 8kB 5.791e+06 5.791e+06 ... 5.781e+06 5.781e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %% [markdown]
# Attributes

# %%
sample.attrs
# Out:
# {'AREA_OR_POINT': 'Area', 'scale_factor': 1.0, 'add_offset': 0.0}

# %% [markdown]
# Image geospatial bounds

# %%
sample.rio.bounds()
# Out:
# (590520.0, 5780620.0, 600530.0, 5790630.0)

# %% [markdown]
# Coordinate reference system

# %%
sample.rio.crs
# Out:
# CRS.from_wkt('PROJCS["WGS 84 / UTM zone 31N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",3],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32631"]]')

# %% [markdown]
# # Visualise data

# %%
sample.plot()
# Out:
# (array([2.568546e+06, 4.036030e+05, 2.750700e+04, 5.593000e+03,
#         6.200000e+02, 8.000000e+01, 3.600000e+01, 1.500000e+01,
#         1.000000e+00, 2.000000e+00]),
#  array([    0. ,  1165.2,  2330.4,  3495.6,  4660.8,  5826. ,  6991.2,
#          8156.4,  9321.6, 10486.8, 11652. ]),
#  <BarContainer object of 10 artists>)
