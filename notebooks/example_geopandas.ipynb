# %%
import geopandas
import rioxarray

# %%
sample = rioxarray.open_rasterio("../images/sample.tif")

# %%
sample
# Out:
# <xarray.DataArray (band: 3, y: 1001, x: 1001)> Size: 6MB
# [3006003 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 8kB 5.905e+05 5.905e+05 ... 6.005e+05 6.005e+05
#   * y            (y) float64 8kB 5.791e+06 5.791e+06 ... 5.781e+06 5.781e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
sample[0].to_pandas().head()
# Out:
# x          590525.0  590535.0  590545.0  590555.0  590565.0  590575.0  \
# y
# 5790625.0         0       799       788       779       799       799
# 5790615.0         0       774       792       804       800       799
# 5790605.0         0       797       801       801       787       793
# 5790595.0         0       806       790       797       801       789
# 5790585.0         0       827       845       807       833       818
#
# x          590585.0  590595.0  590605.0  590615.0  ...  600435.0  600445.0  \
# y                                                  ...
# 5790625.0       798       789       787       787  ...       984      1170
# 5790615.0       781       806       808       795  ...      1176      1054
# 5790605.0       788       808       807       796  ...      1106       961
# 5790595.0       788       793       793       787  ...       983       999
# 5790585.0       813       806       803       794  ...       960       984
#
# ...

# %%
band_0 = geopandas.GeoDataFrame(array[0].to_pandas())

# %%
band_0.head()
# Out:
#             0
# x
# 590525.0    0
# 590535.0  330
# 590545.0  322
# 590555.0  324
# 590565.0  322
